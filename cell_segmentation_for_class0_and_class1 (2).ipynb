# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir "/content/salam"
# !cp "/content/drive/MyDrive/cell_morphology/roi1/raw_image_yellow.tif" "/content/salam"
# !cp "/content/drive/MyDrive/cell_morphology/roi2/roi_2_210419_S01_123_frames_only_tumor_cells_without_edges_again_yellow.tif" "/content/salam"
#!cp "/content/drive/MyDrive/cell_morphology/roi3/Substac_225_325roi_3_210419_S01_without_tumor_cells_and_without_edges_yellow.tif" "/content/salam"
# !cp "/content/drive/MyDrive/cell_morphology/roi1/annotation_Salam_JT_110123.tif" "/content/salam"
# !cp "/content/drive/MyDrive/cell_morphology/roi2/roi_2_210419_S01_annotations_Michele_Amelie_JT_220523_123_frames_for_only_tumor_cells_new.tif" "/content/salam"
#!cp "/content/drive/MyDrive/cell_morphology/roi3/class2_322.tif" "/content/salam"
#!cp "/content/drive/MyDrive/class4/image_roi4_180_frames_without_edges_yellow.tif" "/content/salam"
#!cp "/content/drive/MyDrive/class4/annotation_JT_AS_290523_unit32.tif" "/content/salam"
#!cp "/content/drive/MyDrive/class4/image_roi4_180_frames_without_edges_yellow.tif" "/content/salam"
#!cp "/content/drive/MyDrive/class4/annotation_JT_AS_290523_unit32_roi4_rgb.tif" "/content/salam"

# %%
# !mkdir '/content/raw_data_dir1' 
# !mkdir '/content/raw_data_dir1/class1'
# !mkdir '/content/raw_data_dir1/class1/images1'
# !mkdir '/content/raw_data_dir1/class1/masks1'
# !mkdir '/content/raw_data_dir1/class2'
# !mkdir '/content/raw_data_dir1/class2/images2'
# !mkdir '/content/raw_data_dir1/class2/masks2'

# %%
from PIL import Image, ImageSequence

im = Image.open("/content/salam/raw_image_yellow.tif")   #/content/salam/image.tif

for i, page in enumerate(ImageSequence.Iterator(im)):
    page.save("/content/raw_data_dir1/class1/images1/class1-{}.png".format(i))

# %%
from PIL import Image

# Load the multi-page TIFF image
image = Image.open('/content/salam/annotation_Salam_JT_110123.tif')
for i in range(image.n_frames):
    image.seek(i)
    # Convert RGB to binary (black and white)
    binary_image = image.convert('1')
    binary_image.save(f'/content/raw_data_dir1/class1/masks1/class1-{i}.png', 'PNG')

# %%
from PIL import Image, ImageSequence

im = Image.open("/content/salam/roi_2_210419_S01_123_frames_only_tumor_cells_without_edges_again_yellow.tif")   #/content/salam/image.tif

for i, page in enumerate(ImageSequence.Iterator(im)):
    page.save("/content/raw_data_dir1/class2/images2/class2-{}.png".format(i))

# %%
from PIL import Image

# Load the multi-page TIFF image
image = Image.open('/content/salam/roi_2_210419_S01_annotations_Michele_Amelie_JT_220523_123_frames_for_only_tumor_cells_new.tif')
for i in range(image.n_frames):
    image.seek(i)
    # Convert RGB to binary (black and white)
    binary_image = image.convert('1')
    binary_image.save(f'/content/raw_data_dir1/class2/masks2/class2-{i}.png', 'PNG')

# %%
# !pip install efficientnet_pytorch > /dev/null
# !pip install albumentations > /dev/null

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.optimizers import SGD, RMSprop
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dense, MaxPooling2D, Dropout, concatenate, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import os
import numpy as np
import itertools
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import shutil
import os
import cv2
import time
import numpy as np
import pandas as pd
from tqdm import tqdm
import gc; gc.collect()
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.utils.data as D
import torch.nn.functional as F
from PIL import Image
import os
import pandas as pd
from efficientnet_pytorch import EfficientNet
import torchvision
from torchvision import transforms as T
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import torch
import os
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
from efficientnet_pytorch import EfficientNet
from keras.utils import to_categorical
# Data preprocessing
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from glob import glob
from PIL import Image
import os
import random
import cv2
import keras
from keras.models import Sequential, Model,load_model
from keras.layers import Activation,Dense, Dropout, Flatten, Convolution2D, MaxPooling2D,MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
from keras import backend as K
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers.normalization import batch_normalization
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras import regularizers
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import img_to_array
from keras.callbacks import ReduceLROnPlateau, EarlyStopping,ModelCheckpoint
from keras.metrics import PrecisionAtRecall,Recall 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
import os
import multiprocessing as mp
from PIL import Image
from numpy.random import seed
seed(0)
import tensorflow
tensorflow.random.set_seed(0)

# %%
classes = ['class1', 'class2']
image_data = []
mask_data = []
for class_name in classes:
    class_index = class_name[-1]
    images_path = sorted(os.listdir('/content/raw_data_dir1/{}/images{}/'.format(class_name, class_index)))
    for image_name in images_path:
        image = cv2.imread('/content/raw_data_dir1/{}/images{}/{}'.format(class_name, class_index, image_name), 0)
        image = cv2.resize(image, dsize=(768, 512), interpolation=cv2.INTER_AREA)
        image_data.append(np.array(image))
    mask_path = sorted(os.listdir('/content/raw_data_dir1/{}/masks{}/'.format(class_name, class_index)))
    for mask_name in mask_path:
        mask = cv2.imread('/content/raw_data_dir1/{}/masks{}/{}'.format(class_name, class_index, mask_name), 0)
        mask = cv2.resize(mask, dsize=(768, 512), interpolation=cv2.INTER_AREA)
        mask_data.append(np.array(mask))
image_data = np.expand_dims(np.array(image_data), 3) / 255.0
mask_data = np.expand_dims(np.array(mask_data), 3) / 255.0

#image_data = image_data.astype('float32') / 255.0    #data = np.array(data, dtype=np.float32)
#mask_data = mask_data.astype('float32') / 255.0

#image_data = np.expand_dims(np.array(image_data).astype('float32'), axis=3)
#mask_data = np.expand_dims(np.array(mask_data).astype('float32'), axis=3)
#image_data = np.expand_dims(np.array(image_data).astype('float32') / 255.0, axis=3)
#mask_data = np.expand_dims(np.array(mask_data).astype('float32') / 255.0, axis=3)

# %%
#print()
print(image_data.shape, mask_data.shape)
# Out:
# (203, 512, 768, 1) (203, 512, 768, 1)

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(20,20))
ax[0].imshow(np.squeeze(image_data[78]))
ax[0].set_title('image')
ax[1].imshow(np.squeeze(mask_data[78]))
ax[0].set_title('image')
fig.show()

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(20,20))
ax[0].imshow(np.squeeze(image_data[95]))
ax[0].set_title('image')
ax[1].imshow(np.squeeze(mask_data[95]))
ax[0].set_title('image')
fig.show()

# %%
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.metrics import binary_crossentropy
from tensorflow.keras.metrics import sparse_categorical_accuracy
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.losses import categorical_crossentropy
from keras.metrics import binary_accuracy
mask_data_categorical = to_categorical(mask_data, num_classes=2)
# U-net model
s = Input((image_data.shape[1], image_data.shape[2], image_data.shape[3]))
# Contraction path
c1 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = Dropout(0.2)(c1)
c1 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = MaxPooling2D((2, 2))(c1)

c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = Dropout(0.3)(c2)
c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = MaxPooling2D((2, 2))(c2)

c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = Dropout(0.4)(c3)
c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)

# Expansive path
u4 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c3)
u4 = concatenate([u4, c2])
c4 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u4)
c4 = Dropout(0.4)(c4)
c4 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)

u5 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(c4)
u5 = concatenate([u5, c1], axis=3)
c5 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u5)
c5 = Dropout(0.3)(c5)
c5 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
outputs = Conv2D(1, (1, 1), activation='sigmoid')(c5)

model = Model(inputs=[s], outputs=[outputs])
model.compile(optimizer='adam', loss=binary_crossentropy, metrics=[binary_accuracy])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 768, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 768, 8)  80          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 512, 768, 8)  0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 512, 768, 8)  584         ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 384, 8)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 256, 384, 16  1168        ['max_pooling2d[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 256, 384, 16  0           ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 384, 16  2320        ['dropout_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 192, 16  0          ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 192, 32  4640        ['max_pooling2d_1[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 128, 192, 32  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 192, 32  9248        ['dropout_2[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 256, 384, 16  2064       ['conv2d_5[0][0]']
#  ose)                           )
#
#  concatenate (Concatenate)      (None, 256, 384, 32  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 384, 16  4624        ['concatenate[0][0]']
#                                 )
#
#  dropout_3 (Dropout)            (None, 256, 384, 16  0           ['conv2d_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 384, 16  2320        ['dropout_3[0][0]']
#                                 )
#
#  conv2d_transpose_1 (Conv2DTran  (None, 512, 768, 8)  520        ['conv2d_7[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 512, 768, 16  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 512, 768, 8)  1160        ['concatenate_1[0][0]']
#
#  dropout_4 (Dropout)            (None, 512, 768, 8)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 512, 768, 8)  584         ['dropout_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 512, 768, 1)  9           ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 29,321
# Trainable params: 29,321
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
X_train, X_test, y_train, y_test = train_test_split(image_data, mask_data, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)
'''
# Convert labels to one-hot encoding
num_classes = 3  # Number of classes
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)
'''
print('train data size:', X_train.shape[0])
print('validation data size:', X_val.shape[0])
print('test data size:', X_test.shape[0])
# Out:
# train data size: 145
# validation data size: 17
# test data size: 41

# %%
history = model.fit(x = X_train,
                    y = y_train,
                    batch_size = 8,
                    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)],
                    validation_data = (X_val, y_val),
                    verbose = 1,
                    epochs = 200)
# Out:
# Epoch 1/200
# 19/19 [==============================] - 24s 301ms/step - loss: 0.4063 - binary_accuracy: 0.9433 - val_loss: 0.1382 - val_binary_accuracy: 0.9889
# Epoch 2/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0953 - binary_accuracy: 0.9876 - val_loss: 0.0938 - val_binary_accuracy: 0.9889
# Epoch 3/200
# 19/19 [==============================] - 5s 243ms/step - loss: 0.0487 - binary_accuracy: 0.9889 - val_loss: 0.1152 - val_binary_accuracy: 0.9889
# Epoch 4/200
# 19/19 [==============================] - 5s 243ms/step - loss: 0.0368 - binary_accuracy: 0.9889 - val_loss: 0.1313 - val_binary_accuracy: 0.9889
# Epoch 5/200
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0306 - binary_accuracy: 0.9889 - val_loss: 0.1108 - val_binary_accuracy: 0.9889
# Epoch 6/200
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0265 - binary_accuracy: 0.9889 - val_loss: 0.0671 - val_binary_accuracy: 0.9889
# Epoch 7/200
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0240 - binary_accuracy: 0.9889 - val_loss: 0.0294 - val_binary_accuracy: 0.9889
# Epoch 8/200
# 19/19 [==============================] - 5s 248ms/step - loss: 0.0228 - binary_accuracy: 0.9889 - val_loss: 0.0238 - val_binary_accuracy: 0.9889
# Epoch 9/200
# 19/19 [==============================] - 5s 248ms/step - loss: 0.0219 - binary_accuracy: 0.9889 - val_loss: 0.0268 - val_binary_accuracy: 0.9889
# Epoch 10/200
# 19/19 [==============================] - 5s 246ms/step - loss: 0.0210 - binary_accuracy: 0.9889 - val_loss: 0.0280 - val_binary_accuracy: 0.9889
# Epoch 11/200
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0211 - binary_accuracy: 0.9889 - val_loss: 0.0328 - val_binary_accuracy: 0.9889
# Epoch 12/200
# 19/19 [==============================] - 5s 250ms/step - loss: 0.0211 - binary_accuracy: 0.9889 - val_loss: 0.0276 - val_binary_accuracy: 0.9889
# Epoch 13/200
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0198 - binary_accuracy: 0.9889 - val_loss: 0.0229 - val_binary_accuracy: 0.9889
# Epoch 14/200
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0195 - binary_accuracy: 0.9889 - val_loss: 0.0226 - val_binary_accuracy: 0.9889
# Epoch 15/200
# 19/19 [==============================] - 5s 251ms/step - loss: 0.0192 - binary_accuracy: 0.9889 - val_loss: 0.0250 - val_binary_accuracy: 0.9889
# Epoch 16/200
# 19/19 [==============================] - 5s 251ms/step - loss: 0.0189 - binary_accuracy: 0.9889 - val_loss: 0.0243 - val_binary_accuracy: 0.9889
# Epoch 17/200
# 19/19 [==============================] - 5s 253ms/step - loss: 0.0188 - binary_accuracy: 0.9889 - val_loss: 0.0245 - val_binary_accuracy: 0.9889
# Epoch 18/200
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0186 - binary_accuracy: 0.9889 - val_loss: 0.0252 - val_binary_accuracy: 0.9889
# Epoch 19/200
# 19/19 [==============================] - 5s 257ms/step - loss: 0.0184 - binary_accuracy: 0.9889 - val_loss: 0.0217 - val_binary_accuracy: 0.9889
# Epoch 20/200
# 19/19 [==============================] - 5s 254ms/step - loss: 0.0188 - binary_accuracy: 0.9889 - val_loss: 0.0222 - val_binary_accuracy: 0.9889
# Epoch 21/200
# 19/19 [==============================] - 5s 253ms/step - loss: 0.0184 - binary_accuracy: 0.9889 - val_loss: 0.0254 - val_binary_accuracy: 0.9889
# Epoch 22/200
# 19/19 [==============================] - 5s 255ms/step - loss: 0.0183 - binary_accuracy: 0.9889 - val_loss: 0.0220 - val_binary_accuracy: 0.9889
# Epoch 23/200
# 19/19 [==============================] - 5s 253ms/step - loss: 0.0180 - binary_accuracy: 0.9889 - val_loss: 0.0231 - val_binary_accuracy: 0.9889
# Epoch 24/200
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0177 - binary_accuracy: 0.9889 - val_loss: 0.0206 - val_binary_accuracy: 0.9889
# Epoch 25/200
# 19/19 [==============================] - 5s 257ms/step - loss: 0.0176 - binary_accuracy: 0.9889 - val_loss: 0.0196 - val_binary_accuracy: 0.9889
# Epoch 26/200
# 19/19 [==============================] - 5s 253ms/step - loss: 0.0177 - binary_accuracy: 0.9889 - val_loss: 0.0215 - val_binary_accuracy: 0.9889
# Epoch 27/200
# 19/19 [==============================] - 5s 255ms/step - loss: 0.0176 - binary_accuracy: 0.9889 - val_loss: 0.0218 - val_binary_accuracy: 0.9889
# Epoch 28/200
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0174 - binary_accuracy: 0.9889 - val_loss: 0.0194 - val_binary_accuracy: 0.9889
# Epoch 29/200
# 19/19 [==============================] - 5s 256ms/step - loss: 0.0173 - binary_accuracy: 0.9889 - val_loss: 0.0197 - val_binary_accuracy: 0.9889
# Epoch 30/200
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0173 - binary_accuracy: 0.9889 - val_loss: 0.0204 - val_binary_accuracy: 0.9889
# Epoch 31/200
# 19/19 [==============================] - 5s 256ms/step - loss: 0.0174 - binary_accuracy: 0.9889 - val_loss: 0.0195 - val_binary_accuracy: 0.9889
# Epoch 32/200
# 19/19 [==============================] - 5s 255ms/step - loss: 0.0172 - binary_accuracy: 0.9889 - val_loss: 0.0194 - val_binary_accuracy: 0.9889
# Epoch 33/200
# 19/19 [==============================] - 5s 257ms/step - loss: 0.0171 - binary_accuracy: 0.9889 - val_loss: 0.0193 - val_binary_accuracy: 0.9889
# Epoch 34/200
# 19/19 [==============================] - 5s 255ms/step - loss: 0.0171 - binary_accuracy: 0.9889 - val_loss: 0.0189 - val_binary_accuracy: 0.9889
# Epoch 35/200
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0170 - binary_accuracy: 0.9889 - val_loss: 0.0191 - val_binary_accuracy: 0.9889
# Epoch 36/200
# 19/19 [==============================] - 5s 258ms/step - loss: 0.0173 - binary_accuracy: 0.9889 - val_loss: 0.0171 - val_binary_accuracy: 0.9889
# Epoch 37/200
# 19/19 [==============================] - 5s 258ms/step - loss: 0.0174 - binary_accuracy: 0.9889 - val_loss: 0.0196 - val_binary_accuracy: 0.9889
# Epoch 38/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0170 - binary_accuracy: 0.9889 - val_loss: 0.0182 - val_binary_accuracy: 0.9889
# Epoch 39/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0168 - binary_accuracy: 0.9889 - val_loss: 0.0184 - val_binary_accuracy: 0.9889
# Epoch 40/200
# 19/19 [==============================] - 5s 256ms/step - loss: 0.0168 - binary_accuracy: 0.9889 - val_loss: 0.0179 - val_binary_accuracy: 0.9889
# Epoch 41/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0167 - binary_accuracy: 0.9889 - val_loss: 0.0181 - val_binary_accuracy: 0.9889
# Epoch 42/200
# Epoch 60/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0164 - binary_accuracy: 0.9889 - val_loss: 0.0167 - val_binary_accuracy: 0.9889
# Epoch 61/200
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0163 - binary_accuracy: 0.9889 - val_loss: 0.0167 - val_binary_accuracy: 0.9889
# Epoch 62/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0161 - binary_accuracy: 0.9889 - val_loss: 0.0164 - val_binary_accuracy: 0.9889
# Epoch 63/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0161 - binary_accuracy: 0.9889 - val_loss: 0.0164 - val_binary_accuracy: 0.9889
# Epoch 64/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0160 - binary_accuracy: 0.9889 - val_loss: 0.0162 - val_binary_accuracy: 0.9889
# Epoch 65/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0160 - binary_accuracy: 0.9889 - val_loss: 0.0166 - val_binary_accuracy: 0.9889
# Epoch 66/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0160 - binary_accuracy: 0.9889 - val_loss: 0.0161 - val_binary_accuracy: 0.9889
# Epoch 67/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0160 - binary_accuracy: 0.9889 - val_loss: 0.0161 - val_binary_accuracy: 0.9889
# Epoch 68/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0161 - binary_accuracy: 0.9889 - val_loss: 0.0162 - val_binary_accuracy: 0.9889
# Epoch 69/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0160 - binary_accuracy: 0.9889 - val_loss: 0.0161 - val_binary_accuracy: 0.9889
# Epoch 70/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0160 - binary_accuracy: 0.9889 - val_loss: 0.0162 - val_binary_accuracy: 0.9889
# Epoch 71/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0159 - binary_accuracy: 0.9889 - val_loss: 0.0160 - val_binary_accuracy: 0.9889
# Epoch 72/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0159 - binary_accuracy: 0.9889 - val_loss: 0.0162 - val_binary_accuracy: 0.9889
# Epoch 73/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0158 - binary_accuracy: 0.9889 - val_loss: 0.0161 - val_binary_accuracy: 0.9889
# Epoch 74/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0160 - binary_accuracy: 0.9889 - val_loss: 0.0163 - val_binary_accuracy: 0.9889
# Epoch 75/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0159 - binary_accuracy: 0.9889 - val_loss: 0.0167 - val_binary_accuracy: 0.9889
# Epoch 76/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0160 - binary_accuracy: 0.9889 - val_loss: 0.0161 - val_binary_accuracy: 0.9889
# Epoch 77/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0159 - binary_accuracy: 0.9889 - val_loss: 0.0162 - val_binary_accuracy: 0.9889
# Epoch 113/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0153 - binary_accuracy: 0.9902 - val_loss: 0.0154 - val_binary_accuracy: 0.9901
# Epoch 114/200
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0153 - binary_accuracy: 0.9902 - val_loss: 0.0155 - val_binary_accuracy: 0.9901
# Epoch 115/200
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0153 - val_binary_accuracy: 0.9901
# Epoch 116/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0153 - val_binary_accuracy: 0.9902
# Epoch 117/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0154 - val_binary_accuracy: 0.9901
# Epoch 118/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0154 - val_binary_accuracy: 0.9901
# Epoch 119/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0154 - val_binary_accuracy: 0.9900
# Epoch 120/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0155 - val_binary_accuracy: 0.9902
# Epoch 121/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0153 - val_binary_accuracy: 0.9901
# Epoch 122/200
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0151 - binary_accuracy: 0.9902 - val_loss: 0.0153 - val_binary_accuracy: 0.9901
# Epoch 123/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0151 - binary_accuracy: 0.9902 - val_loss: 0.0153 - val_binary_accuracy: 0.9902
# Epoch 124/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0151 - binary_accuracy: 0.9902 - val_loss: 0.0154 - val_binary_accuracy: 0.9901
# Epoch 125/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0151 - binary_accuracy: 0.9902 - val_loss: 0.0154 - val_binary_accuracy: 0.9901
# Epoch 126/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0154 - val_binary_accuracy: 0.9900
# Epoch 127/200
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0152 - binary_accuracy: 0.9902 - val_loss: 0.0153 - val_binary_accuracy: 0.9902
# Epoch 128/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0151 - binary_accuracy: 0.9902 - val_loss: 0.0154 - val_binary_accuracy: 0.9901
# Epoch 129/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0151 - binary_accuracy: 0.9902 - val_loss: 0.0152 - val_binary_accuracy: 0.9902
# Epoch 130/200
# Epoch 166/200
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0145 - binary_accuracy: 0.9903 - val_loss: 0.0148 - val_binary_accuracy: 0.9902
# Epoch 167/200
# 19/19 [==============================] - 5s 265ms/step - loss: 0.0146 - binary_accuracy: 0.9903 - val_loss: 0.0148 - val_binary_accuracy: 0.9902
# Epoch 168/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0147 - binary_accuracy: 0.9903 - val_loss: 0.0148 - val_binary_accuracy: 0.9902
# Epoch 169/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0145 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 170/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0146 - binary_accuracy: 0.9903 - val_loss: 0.0146 - val_binary_accuracy: 0.9902
# Epoch 171/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0147 - binary_accuracy: 0.9903 - val_loss: 0.0146 - val_binary_accuracy: 0.9902
# Epoch 172/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0145 - binary_accuracy: 0.9903 - val_loss: 0.0146 - val_binary_accuracy: 0.9902
# Epoch 173/200
# 19/19 [==============================] - 5s 265ms/step - loss: 0.0146 - binary_accuracy: 0.9903 - val_loss: 0.0146 - val_binary_accuracy: 0.9902
# Epoch 174/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0144 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 175/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0144 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 176/200
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0144 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9903
# Epoch 177/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0144 - binary_accuracy: 0.9903 - val_loss: 0.0144 - val_binary_accuracy: 0.9902
# Epoch 178/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0144 - binary_accuracy: 0.9903 - val_loss: 0.0144 - val_binary_accuracy: 0.9903
# Epoch 179/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0144 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 180/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 181/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0144 - val_binary_accuracy: 0.9902
# Epoch 182/200
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0143 - val_binary_accuracy: 0.9903
# Epoch 183/200
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 184/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0143 - val_binary_accuracy: 0.9903
# Epoch 185/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 186/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0144 - val_binary_accuracy: 0.9902
# Epoch 187/200
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0142 - binary_accuracy: 0.9904 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 188/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0144 - val_binary_accuracy: 0.9902
# Epoch 189/200
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0144 - binary_accuracy: 0.9903 - val_loss: 0.0147 - val_binary_accuracy: 0.9902
# Epoch 190/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0145 - val_binary_accuracy: 0.9902
# Epoch 191/200
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0146 - val_binary_accuracy: 0.9902
# Epoch 192/200
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0142 - binary_accuracy: 0.9903 - val_loss: 0.0143 - val_binary_accuracy: 0.9902
# Epoch 193/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0146 - val_binary_accuracy: 0.9902
# Epoch 194/200
# 19/19 [==============================] - 5s 265ms/step - loss: 0.0143 - binary_accuracy: 0.9903 - val_loss: 0.0144 - val_binary_accuracy: 0.9902
# Epoch 195/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0142 - binary_accuracy: 0.9903 - val_loss: 0.0142 - val_binary_accuracy: 0.9903
# Epoch 196/200
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0141 - binary_accuracy: 0.9903 - val_loss: 0.0142 - val_binary_accuracy: 0.9903
# Epoch 197/200
# 19/19 [==============================] - 5s 265ms/step - loss: 0.0141 - binary_accuracy: 0.9904 - val_loss: 0.0143 - val_binary_accuracy: 0.9903
# Epoch 198/200
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0141 - binary_accuracy: 0.9903 - val_loss: 0.0142 - val_binary_accuracy: 0.9903
# Epoch 199/200
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0141 - binary_accuracy: 0.9903 - val_loss: 0.0141 - val_binary_accuracy: 0.9902
# Epoch 200/200
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0140 - binary_accuracy: 0.9904 - val_loss: 0.0146 - val_binary_accuracy: 0.9902

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(13,5))

ax[0].plot(history.history['binary_accuracy'])
ax[0].plot(history.history['val_binary_accuracy'])
ax[0].set_title('model accuracy')
ax[0].set_ylabel('accuracy')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'val'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('model loss')
ax[1].set_ylabel('val_loss')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'val'], loc='upper right')

fig.show()

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 180ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
import matplotlib.pyplot as plt

# %%
rndm_img = np.random.randint(0, len(X_test))

fig, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].imshow(np.squeeze(X_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt), cmap='gray', vmin=0, vmax=1)
ax[2].set_title('prediction mask')

plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
rndm_img = np.random.randint(0, len(X_test))

fig, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].imshow(np.squeeze(X_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt), cmap='gray', vmin=0, vmax=1)
ax[2].set_title('prediction mask')

plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
rndm_img = np.random.randint(0, len(X_test))

fig, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].imshow(np.squeeze(X_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt), cmap='gray', vmin=0, vmax=1)
ax[2].set_title('prediction mask')

plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
