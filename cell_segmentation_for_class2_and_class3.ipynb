# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir "/content/salam"
#!cp "/content/drive/MyDrive/cell_morphology/roi1/raw_image_yellow.tif" "/content/salam"
#!cp "/content/drive/MyDrive/cell_morphology/roi2/roi_2_210419_S01_123_frames_only_tumor_cells_without_edges_again_yellow.tif" "/content/salam"
# !cp "/content/drive/MyDrive/cell_morphology/roi3/Substac_225_325roi_3_210419_S01_without_tumor_cells_and_without_edges_yellow.tif" "/content/salam"
#!cp "/content/drive/MyDrive/cell_morphology/roi1/annotation_Salam_JT_110123.tif" "/content/salam"
#!cp "/content/drive/MyDrive/cell_morphology/roi2/roi_2_210419_S01_annotations_Michele_Amelie_JT_220523_123_frames_for_only_tumor_cells_new.tif" "/content/salam"
# !cp "/content/drive/MyDrive/cell_morphology/roi3/class2_322.tif" "/content/salam"
#!cp "/content/drive/MyDrive/class4/image_roi4_180_frames_without_edges_yellow.tif" "/content/salam"
#!cp "/content/drive/MyDrive/class4/annotation_JT_AS_290523_unit32.tif" "/content/salam"
# !cp "/content/drive/MyDrive/cell_morphology/roi4/image_roi4_180_frames_without_edges_yellow.tif" "/content/salam"
# !cp "/content/drive/MyDrive/cell_morphology/roi4/annotation_JT_AS_290523_unit32_roi4_rgb.tif" "/content/salam"

# %%
# !mkdir '/content/raw_data_dir1' 
# !mkdir '/content/raw_data_dir1/class1'
# !mkdir '/content/raw_data_dir1/class1/images1'
# !mkdir '/content/raw_data_dir1/class1/masks1'
# !mkdir '/content/raw_data_dir1/class2'
# !mkdir '/content/raw_data_dir1/class2/images2'
# !mkdir '/content/raw_data_dir1/class2/masks2'

# %%
from PIL import Image, ImageSequence

im = Image.open("/content/salam/Substac_225_325roi_3_210419_S01_without_tumor_cells_and_without_edges_yellow.tif")   #/content/salam/image.tif

for i, page in enumerate(ImageSequence.Iterator(im)):
    page.save("/content/raw_data_dir1/class1/images1/class1-{}.png".format(i))

# %%
from PIL import Image

# Load the multi-page TIFF image
image = Image.open('/content/salam/class2_322.tif')
for i in range(image.n_frames):
    image.seek(i)
    # Convert RGB to binary (black and white)
    binary_image = image.convert('1')
    binary_image.save(f'/content/raw_data_dir1/class1/masks1/class1-{i}.png', 'PNG')

# %%
from PIL import Image, ImageSequence

im = Image.open("/content/salam/image_roi4_180_frames_without_edges_yellow.tif")   #/content/salam/image.tif

for i, page in enumerate(ImageSequence.Iterator(im)):
    page.save("/content/raw_data_dir1/class2/images2/class2-{}.png".format(i))

# %%
from PIL import Image

# Load the multi-page TIFF image
image = Image.open('/content/salam/annotation_JT_AS_290523_unit32_roi4_rgb.tif')
for i in range(image.n_frames):
    image.seek(i)
    # Convert RGB to binary (black and white)
    binary_image = image.convert('1')
    binary_image.save(f'/content/raw_data_dir1/class2/masks2/class2-{i}.png', 'PNG')

# %%
# !pip install efficientnet_pytorch > /dev/null
# !pip install albumentations > /dev/null

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.optimizers import SGD, RMSprop
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dense, MaxPooling2D, Dropout, concatenate, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import os
import numpy as np
import itertools
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import shutil
import os
import cv2
import time
import numpy as np
import pandas as pd
from tqdm import tqdm
import gc; gc.collect()
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.utils.data as D
import torch.nn.functional as F
from PIL import Image
import os
import pandas as pd
from efficientnet_pytorch import EfficientNet
import torchvision
from torchvision import transforms as T
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import torch
import os
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
from efficientnet_pytorch import EfficientNet
from keras.utils import to_categorical
# Data preprocessing
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from glob import glob
from PIL import Image
import os
import random
import cv2
import keras
from keras.models import Sequential, Model,load_model
from keras.layers import Activation,Dense, Dropout, Flatten, Convolution2D, MaxPooling2D,MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
from keras import backend as K
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers.normalization import batch_normalization
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras import regularizers
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import img_to_array
from keras.callbacks import ReduceLROnPlateau, EarlyStopping,ModelCheckpoint
from keras.metrics import PrecisionAtRecall,Recall 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
import os
import multiprocessing as mp
from PIL import Image
from numpy.random import seed
seed(0)
import tensorflow
tensorflow.random.set_seed(0)

# %%
classes = ['class1', 'class2']
image_data = []
mask_data = []
for class_name in classes:
    class_index = class_name[-1]
    images_path = sorted(os.listdir('/content/raw_data_dir1/{}/images{}/'.format(class_name, class_index)))
    for image_name in images_path:
        image = cv2.imread('/content/raw_data_dir1/{}/images{}/{}'.format(class_name, class_index, image_name), 0)
        image = cv2.resize(image, dsize=(768, 512), interpolation=cv2.INTER_AREA)
        image_data.append(np.array(image))
    mask_path = sorted(os.listdir('/content/raw_data_dir1/{}/masks{}/'.format(class_name, class_index)))
    for mask_name in mask_path:
        mask = cv2.imread('/content/raw_data_dir1/{}/masks{}/{}'.format(class_name, class_index, mask_name), 0)
        mask = cv2.resize(mask, dsize=(768, 512), interpolation=cv2.INTER_AREA)
        mask_data.append(np.array(mask))
image_data = np.expand_dims(np.array(image_data), 3) / 255.0
mask_data = np.expand_dims(np.array(mask_data), 3) / 255.0

#image_data = image_data.astype('float32') / 255.0    #data = np.array(data, dtype=np.float32)
#mask_data = mask_data.astype('float32') / 255.0

#image_data = np.expand_dims(np.array(image_data).astype('float32'), axis=3)
#mask_data = np.expand_dims(np.array(mask_data).astype('float32'), axis=3)
#image_data = np.expand_dims(np.array(image_data).astype('float32') / 255.0, axis=3)
#mask_data = np.expand_dims(np.array(mask_data).astype('float32') / 255.0, axis=3)

# %%
#print()
print(image_data.shape, mask_data.shape)
# Out:
# (281, 512, 768, 1) (281, 512, 768, 1)

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(20,20))
ax[0].imshow(np.squeeze(image_data[78]))
ax[0].set_title('image')
ax[1].imshow(np.squeeze(mask_data[78]))
ax[0].set_title('image')
fig.show()

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(20,20))
ax[0].imshow(np.squeeze(image_data[95]))
ax[0].set_title('image')
ax[1].imshow(np.squeeze(mask_data[95]))
ax[0].set_title('image')
fig.show()

# %%
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.metrics import binary_crossentropy
from tensorflow.keras.metrics import sparse_categorical_accuracy
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.losses import categorical_crossentropy
from keras.metrics import binary_accuracy
#mask_data_categorical = to_categorical(mask_data, num_classes=2)
# U-net model
s = Input((image_data.shape[1], image_data.shape[2], image_data.shape[3]))
# Contraction path
c1 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = Dropout(0.2)(c1)
c1 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = MaxPooling2D((2, 2))(c1)

c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = Dropout(0.3)(c2)
c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = MaxPooling2D((2, 2))(c2)

c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = Dropout(0.4)(c3)
c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)

# Expansive path
u4 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c3)
u4 = concatenate([u4, c2])
c4 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u4)
c4 = Dropout(0.4)(c4)
c4 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)

u5 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(c4)
u5 = concatenate([u5, c1], axis=3)
c5 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u5)
c5 = Dropout(0.3)(c5)
c5 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
outputs = Conv2D(1, (1, 1), activation='sigmoid')(c5)

model = Model(inputs=[s], outputs=[outputs])
model.compile(optimizer='adam', loss=binary_crossentropy, metrics=[binary_accuracy])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 768, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 768, 8)  80          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 512, 768, 8)  0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 512, 768, 8)  584         ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 384, 8)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 256, 384, 16  1168        ['max_pooling2d[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 256, 384, 16  0           ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 384, 16  2320        ['dropout_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 192, 16  0          ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 192, 32  4640        ['max_pooling2d_1[0][0]']
#                                 )
#
#  dropout_2 (Dropout)            (None, 128, 192, 32  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 192, 32  9248        ['dropout_2[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 256, 384, 16  2064       ['conv2d_5[0][0]']
#  ose)                           )
#
#  concatenate (Concatenate)      (None, 256, 384, 32  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 384, 16  4624        ['concatenate[0][0]']
#                                 )
#
#  dropout_3 (Dropout)            (None, 256, 384, 16  0           ['conv2d_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 384, 16  2320        ['dropout_3[0][0]']
#                                 )
#
#  conv2d_transpose_1 (Conv2DTran  (None, 512, 768, 8)  520        ['conv2d_7[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 512, 768, 16  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 512, 768, 8)  1160        ['concatenate_1[0][0]']
#
#  dropout_4 (Dropout)            (None, 512, 768, 8)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 512, 768, 8)  584         ['dropout_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 512, 768, 1)  9           ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 29,321
# Trainable params: 29,321
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
X_train, X_test, y_train, y_test = train_test_split(image_data, mask_data, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)
'''
# Convert labels to one-hot encoding
num_classes = 3  # Number of classes
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)
'''
print('train data size:', X_train.shape[0])
print('validation data size:', X_val.shape[0])
print('test data size:', X_test.shape[0])
# Out:
# train data size: 201
# validation data size: 23
# test data size: 57

# %%
history = model.fit(x = X_train,
                    y = y_train,
                    batch_size = 8,
                    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)],
                    validation_data = (X_val, y_val),
                    verbose = 1,
                    epochs = 100)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 28s 402ms/step - loss: 0.4285 - binary_accuracy: 0.9180 - val_loss: 0.0411 - val_binary_accuracy: 0.9988
# Epoch 2/100
# 26/26 [==============================] - 7s 252ms/step - loss: 0.0472 - binary_accuracy: 0.9988 - val_loss: 0.0263 - val_binary_accuracy: 0.9988
# Epoch 3/100
# 26/26 [==============================] - 7s 257ms/step - loss: 0.0133 - binary_accuracy: 0.9988 - val_loss: 0.0073 - val_binary_accuracy: 0.9988
# Epoch 4/100
# 26/26 [==============================] - 7s 257ms/step - loss: 0.0078 - binary_accuracy: 0.9989 - val_loss: 0.0109 - val_binary_accuracy: 0.9988
# Epoch 5/100
# 26/26 [==============================] - 7s 262ms/step - loss: 0.0056 - binary_accuracy: 0.9989 - val_loss: 0.0178 - val_binary_accuracy: 0.9988
# Epoch 6/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0047 - binary_accuracy: 0.9989 - val_loss: 0.0197 - val_binary_accuracy: 0.9988
# Epoch 7/100
# 26/26 [==============================] - 7s 268ms/step - loss: 0.0044 - binary_accuracy: 0.9989 - val_loss: 0.0164 - val_binary_accuracy: 0.9988
# Epoch 8/100
# 26/26 [==============================] - 7s 272ms/step - loss: 0.0043 - binary_accuracy: 0.9989 - val_loss: 0.0139 - val_binary_accuracy: 0.9988
# Epoch 9/100
# 26/26 [==============================] - 7s 273ms/step - loss: 0.0041 - binary_accuracy: 0.9989 - val_loss: 0.0141 - val_binary_accuracy: 0.9988
# Epoch 10/100
# 26/26 [==============================] - 7s 270ms/step - loss: 0.0040 - binary_accuracy: 0.9989 - val_loss: 0.0112 - val_binary_accuracy: 0.9988
# Epoch 11/100
# 26/26 [==============================] - 7s 268ms/step - loss: 0.0038 - binary_accuracy: 0.9989 - val_loss: 0.0108 - val_binary_accuracy: 0.9988
# Epoch 12/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0037 - binary_accuracy: 0.9989 - val_loss: 0.0087 - val_binary_accuracy: 0.9988
# Epoch 13/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0035 - binary_accuracy: 0.9989 - val_loss: 0.0061 - val_binary_accuracy: 0.9988
# Epoch 14/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0033 - binary_accuracy: 0.9989 - val_loss: 0.0045 - val_binary_accuracy: 0.9988
# Epoch 15/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0032 - binary_accuracy: 0.9989 - val_loss: 0.0043 - val_binary_accuracy: 0.9988
# Epoch 16/100
# 26/26 [==============================] - 7s 262ms/step - loss: 0.0030 - binary_accuracy: 0.9989 - val_loss: 0.0028 - val_binary_accuracy: 0.9988
# Epoch 17/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0029 - binary_accuracy: 0.9989 - val_loss: 0.0028 - val_binary_accuracy: 0.9988
# Epoch 18/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0028 - binary_accuracy: 0.9989 - val_loss: 0.0025 - val_binary_accuracy: 0.9988
# Epoch 19/100
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0027 - binary_accuracy: 0.9989 - val_loss: 0.0024 - val_binary_accuracy: 0.9988
# Epoch 20/100
# 26/26 [==============================] - 7s 272ms/step - loss: 0.0026 - binary_accuracy: 0.9989 - val_loss: 0.0023 - val_binary_accuracy: 0.9988
# Epoch 21/100
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0026 - binary_accuracy: 0.9989 - val_loss: 0.0023 - val_binary_accuracy: 0.9988
# Epoch 22/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0025 - binary_accuracy: 0.9989 - val_loss: 0.0026 - val_binary_accuracy: 0.9988
# Epoch 23/100
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0024 - binary_accuracy: 0.9989 - val_loss: 0.0022 - val_binary_accuracy: 0.9988
# Epoch 24/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0024 - binary_accuracy: 0.9989 - val_loss: 0.0023 - val_binary_accuracy: 0.9988
# Epoch 25/100
# 26/26 [==============================] - 7s 273ms/step - loss: 0.0023 - binary_accuracy: 0.9989 - val_loss: 0.0027 - val_binary_accuracy: 0.9988
# Epoch 26/100
# 26/26 [==============================] - 7s 271ms/step - loss: 0.0023 - binary_accuracy: 0.9989 - val_loss: 0.0024 - val_binary_accuracy: 0.9988
# Epoch 27/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0022 - binary_accuracy: 0.9989 - val_loss: 0.0024 - val_binary_accuracy: 0.9988
# Epoch 28/100
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0022 - binary_accuracy: 0.9989 - val_loss: 0.0022 - val_binary_accuracy: 0.9988
# Epoch 29/100
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0022 - binary_accuracy: 0.9989 - val_loss: 0.0024 - val_binary_accuracy: 0.9988
# Epoch 30/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0022 - binary_accuracy: 0.9989 - val_loss: 0.0019 - val_binary_accuracy: 0.9988
# Epoch 31/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0022 - binary_accuracy: 0.9989 - val_loss: 0.0023 - val_binary_accuracy: 0.9988
# Epoch 32/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0022 - binary_accuracy: 0.9989 - val_loss: 0.0020 - val_binary_accuracy: 0.9988
# Epoch 33/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0021 - binary_accuracy: 0.9989 - val_loss: 0.0019 - val_binary_accuracy: 0.9988
# Epoch 34/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0021 - binary_accuracy: 0.9989 - val_loss: 0.0021 - val_binary_accuracy: 0.9988
# Epoch 35/100
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0021 - binary_accuracy: 0.9989 - val_loss: 0.0019 - val_binary_accuracy: 0.9988
# Epoch 36/100
# 26/26 [==============================] - 7s 273ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0021 - val_binary_accuracy: 0.9988
# Epoch 37/100
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0019 - val_binary_accuracy: 0.9988
# Epoch 38/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0021 - val_binary_accuracy: 0.9988
# Epoch 39/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0019 - val_binary_accuracy: 0.9988
# Epoch 40/100
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0018 - val_binary_accuracy: 0.9988
# Epoch 41/100
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0020 - val_binary_accuracy: 0.9988
# Epoch 42/100
# 26/26 [==============================] - 7s 268ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 43/100
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0018 - val_binary_accuracy: 0.9988
# Epoch 44/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0019 - val_binary_accuracy: 0.9988
# Epoch 45/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0018 - val_binary_accuracy: 0.9988
# Epoch 46/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 47/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 48/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 49/100
# 26/26 [==============================] - 7s 262ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 50/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 51/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0018 - val_binary_accuracy: 0.9988
# Epoch 52/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0016 - val_binary_accuracy: 0.9988
# Epoch 53/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0020 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 54/100
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0018 - val_binary_accuracy: 0.9988
# Epoch 55/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0018 - val_binary_accuracy: 0.9988
# Epoch 56/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 57/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0019 - val_binary_accuracy: 0.9988
# Epoch 58/100
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 59/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 60/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0018 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 61/100
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988
# Epoch 62/100
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0019 - binary_accuracy: 0.9989 - val_loss: 0.0017 - val_binary_accuracy: 0.9988

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(13,5))

ax[0].plot(history.history['binary_accuracy'])
ax[0].plot(history.history['val_binary_accuracy'])
ax[0].set_title('model accuracy')
ax[0].set_ylabel('accuracy')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'val'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('model loss')
ax[1].set_ylabel('val_loss')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'val'], loc='upper right')

fig.show()

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 216ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
rndm_img = np.random.randint(0,len(X_test))

fig, ax = plt.subplots(1,3, figsize=(20,20))
ax[0].imshow(np.squeeze(X_test[rndm_img]))
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]))
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt))
ax[2].set_title('prediction mask')

fig.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
import matplotlib.pyplot as plt

# %%
rndm_img = np.random.randint(0, len(X_test))

fig, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].imshow(np.squeeze(X_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt), cmap='gray', vmin=0, vmax=1)
ax[2].set_title('prediction mask')

plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
rndm_img = np.random.randint(0, len(X_test))

fig, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].imshow(np.squeeze(X_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt), cmap='gray', vmin=0, vmax=1)
ax[2].set_title('prediction mask')

plt.show()
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
rndm_img = np.random.randint(0, len(X_test))

fig, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].imshow(np.squeeze(X_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[0].set_title('real image')

ax[1].imshow(np.squeeze(y_test[rndm_img]), cmap='gray', vmin=0, vmax=1)
ax[1].set_title('real mask')

test_img = np.expand_dims(X_test[rndm_img], axis=0)
rslt = model.predict(test_img)[0]
ax[2].imshow(np.squeeze(rslt), cmap='gray', vmin=0, vmax=1)
ax[2].set_title('prediction mask')

plt.show()
# Out:
# 1/1 [==============================] - 0s 75ms/step
